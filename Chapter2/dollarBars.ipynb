# %% [markdown]
# # 🔵Corn Data

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
from VersaQT.data_manip import *

# %%
plt.rcParams["figure.figsize"] = (10, 6)  # Width=10, Height=6 (in inches)

# %%
soy = yf.Ticker("ZS=F")
soy_history = soy.history(period="1y")
soy_history = soy_history.asfreq("B")

print(soy.info["shortName"])

# Interpolando os dados
soy_history = soy_history.interpolate()

soy_history.reset_index(inplace=True)
# Out:
# Soybean Futures,Mar-2025

# %%
corn = yf.download("ZC=F", start="2020-01-01", end="2023-12-31", interval="1d")
corn
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Close    High     Low    Open  Volume
# Ticker        ZC=F    ZC=F    ZC=F    ZC=F    ZC=F
# Date
# 2020-01-02  391.50  392.00  387.25  387.75  103987
# 2020-01-03  386.50  392.00  385.50  391.50  125931
# 2020-01-06  384.75  387.75  382.75  386.25  112130
# 2020-01-07  384.50  385.75  383.50  385.00   93541
# 2020-01-08  384.25  385.50  382.25  384.00  135523
# ...            ...     ...     ...     ...     ...
# 2023-12-22  473.00  474.00  471.50  472.50   80484
# 2023-12-26  480.25  481.00  471.50  473.00  114198
# 2023-12-27  476.50  480.25  474.50  479.75  107950
# 2023-12-28  474.25  478.75  474.00  476.00   99398
# 2023-12-29  471.25  475.00  470.50  473.75  109649
#
# [1006 rows x 5 columns]

# %%
corn.columns = corn.columns.get_level_values(0)
corn
# Out:
# Price        Close    High     Low    Open  Volume
# Date
# 2020-01-02  391.50  392.00  387.25  387.75  103987
# 2020-01-03  386.50  392.00  385.50  391.50  125931
# 2020-01-06  384.75  387.75  382.75  386.25  112130
# 2020-01-07  384.50  385.75  383.50  385.00   93541
# 2020-01-08  384.25  385.50  382.25  384.00  135523
# ...            ...     ...     ...     ...     ...
# 2023-12-22  473.00  474.00  471.50  472.50   80484
# 2023-12-26  480.25  481.00  471.50  473.00  114198
# 2023-12-27  476.50  480.25  474.50  479.75  107950
# 2023-12-28  474.25  478.75  474.00  476.00   99398
# 2023-12-29  471.25  475.00  470.50  473.75  109649
#
# [1006 rows x 5 columns]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(y=corn.Close, x=corn.index))

fig.show()

# %% [markdown]
# # 🔵Bars
#
# In finance, bars refers to rows in tables. We usually consider different strategies to construct bar - that is, contruct your data.
#
#
# ## 🔵 Time Bars (Time Series)
# The problem with time bars is that they are sampled in a fixed time interval and the market doens't process information at a constant pace. More activity happens following the Open, than the hour around noon.
# - Time bars oversample information during low-activity periods
# - And undersample information during high-activity ones
#
# They also exhibit poor statistical properties

# %% [markdown]
# ## 🔵Dollar Bars
#
# Sample original data every time a pre-defined market value is exchanged.
# - Have better statistical properties
# - Reflect better the market
#
# **Intuição**: Considere um stock que você comprou $1000 e que teve apreciação de 100% em um período. Para vender $1000 dessa ação no final desse período, você só precisá vender metade das participação que você comprou em primeiro lugar.
# - O número de ações trocadas é uma função do valor de cada ação
#
#
# Dollar bars tend to remove behaviours that only appear due to the nature of the price market and on how humans behave.
# - Trying to capture only the significant infomration from the data
# - **Data Quality**

# %% [markdown]
# ### 🔵Implementation

# %% [markdown]
# $$
#     \text{Dollar Volume} = \text{price} * \text{volume}
# $$

# %%
corn['DollarVolume'] = corn['Close'] * corn['Volume']  # Using 'Close'  price for the calculation
corn["CummDollarVolume"] = corn["DollarVolume"].cumsum()

# %% [markdown]
# - Cummulative sum with a dollar threshold
# - Generate BarID
#
# Rows with the same BardID will be condense into a single bar

# %%
dollar_threshold1 = 1_000_000_000
corn1 = corn.__deepcopy__()
corn1["BarId"] = corn1["CummDollarVolume"]//dollar_threshold1
corn1["BarId"] = corn1["BarId"].shift(1, fill_value=0)
corn1 = corn1.reset_index()


dollar_threshold = 1_000_000
corn["BarId"] = corn["CummDollarVolume"]//dollar_threshold
corn["BarId"] = corn["BarId"].shift(1, fill_value=0)
corn = corn.reset_index()
corn.head(20)
# Out:
# Price       Date   Close    High     Low    Open  Volume  DollarVolume  \
# 0     2020-01-02  391.50  392.00  387.25  387.75  103987  4.071091e+07
# 1     2020-01-03  386.50  392.00  385.50  391.50  125931  4.867233e+07
# 2     2020-01-06  384.75  387.75  382.75  386.25  112130  4.314202e+07
# 3     2020-01-07  384.50  385.75  383.50  385.00   93541  3.596651e+07
# 4     2020-01-08  384.25  385.50  382.25  384.00  135523  5.207471e+07
# 5     2020-01-09  383.25  387.00  382.25  383.75  130937  5.018161e+07
# 6     2020-01-10  385.75  386.75  376.50  383.25  226659  8.743371e+07
# 7     2020-01-13  389.50  389.50  385.50  386.50  139994  5.452766e+07
# 8     2020-01-14  389.00  390.50  388.25  389.25  115957  4.510727e+07
# 9     2020-01-15  387.50  390.25  386.50  388.75  141478  5.482272e+07
# 10    2020-01-16  375.50  387.75  375.25  387.25  230557  8.657415e+07
# 11    2020-01-17  389.25  389.50  376.75  377.00  293121  1.140973e+08
# 12    2020-01-21  387.50  389.25  384.25  389.00  182958  7.089622e+07
# 13    2020-01-22  388.75  391.00  386.75  387.50  155603  6.049067e+07
# 14    2020-01-23  393.75  394.00  387.50  388.50  256298  1.009173e+08
# 15    2020-01-24  387.25  393.25  386.50  393.25  196121  7.594786e+07
# 16    2020-01-27  380.50  384.75  377.25  384.25  264471  1.006312e+08
# 17    2020-01-28  386.50  387.00  378.50  382.50  243266  9.402231e+07
# 18    2020-01-29  384.25  388.25  382.75  385.50  136811  5.256963e+07
# 19    2020-01-30  379.50  385.00  378.50  384.50  160206  6.079818e+07
#
# Price  CummDollarVolume   BarId
# 0          4.071091e+07     0.0
# 1          8.938324e+07    40.0
# 2          1.325253e+08    89.0
# 3          1.684918e+08   132.0
# 4          2.205665e+08   168.0
# 5          2.707481e+08   220.0
# 6          3.581818e+08   270.0
# 7          4.127095e+08   358.0
# 8          4.578167e+08   412.0
# 9          5.126395e+08   457.0
# 10         5.992136e+08   512.0
# 11         7.133110e+08   599.0
# 12         7.842072e+08   713.0
# 13         8.446979e+08   784.0
# 14         9.456152e+08   844.0
# 15         1.021563e+09   945.0
# 16         1.122194e+09  1021.0
# 17         1.216217e+09  1122.0
# 18         1.268786e+09  1216.0
# 19         1.329584e+09  1268.0

# %% [markdown]
# Aggregating all variables according to bars
# - Some are summed
# - Others you take the first, max, last, min, etc.

# %%
corn1_dollar_bars = corn1.groupby("BarId").agg({
    "Open": "first",
    "High": "max",
    "Low": "min",
    "Close": "last",
    "Volume": "sum",
    "DollarVolume": "sum",
    "Date": ["first", "last"]
})

corn1_dollar_bars.columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'DollarVolume', 'StartTime', 'EndTime']

# %%
corn_dollar_bars = corn.groupby("BarId").agg({
    "Open": "first",
    "High": "max",
    "Low": "min",
    "Close": "last",
    "Volume": "sum",
    "DollarVolume": "sum",
    "Date": ["first", "last"]
})

corn_dollar_bars.columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'DollarVolume', 'StartTime', 'EndTime']
corn_dollar_bars.head(20)
# Out:
#           Open    High     Low   Close  Volume  DollarVolume  StartTime  \
# BarId
# 0.0     387.75  392.00  387.25  391.50  103987  4.071091e+07 2020-01-02
# 40.0    391.50  392.00  385.50  386.50  125931  4.867233e+07 2020-01-03
# 89.0    386.25  387.75  382.75  384.75  112130  4.314202e+07 2020-01-06
# 132.0   385.00  385.75  383.50  384.50   93541  3.596651e+07 2020-01-07
# 168.0   384.00  385.50  382.25  384.25  135523  5.207471e+07 2020-01-08
# 220.0   383.75  387.00  382.25  383.25  130937  5.018161e+07 2020-01-09
# 270.0   383.25  386.75  376.50  385.75  226659  8.743371e+07 2020-01-10
# 358.0   386.50  389.50  385.50  389.50  139994  5.452766e+07 2020-01-13
# 412.0   389.25  390.50  388.25  389.00  115957  4.510727e+07 2020-01-14
# 457.0   388.75  390.25  386.50  387.50  141478  5.482272e+07 2020-01-15
# 512.0   387.25  387.75  375.25  375.50  230557  8.657415e+07 2020-01-16
# 599.0   377.00  389.50  376.75  389.25  293121  1.140973e+08 2020-01-17
# 713.0   389.00  389.25  384.25  387.50  182958  7.089622e+07 2020-01-21
# 784.0   387.50  391.00  386.75  388.75  155603  6.049067e+07 2020-01-22
# 844.0   388.50  394.00  387.50  393.75  256298  1.009173e+08 2020-01-23
# 945.0   393.25  393.25  386.50  387.25  196121  7.594786e+07 2020-01-24
# 1021.0  384.25  384.75  377.25  380.50  264471  1.006312e+08 2020-01-27
# 1122.0  382.50  387.00  378.50  386.50  243266  9.402231e+07 2020-01-28
# 1216.0  385.50  388.25  382.75  384.25  136811  5.256963e+07 2020-01-29
# 1268.0  384.50  385.00  378.50  379.50  160206  6.079818e+07 2020-01-30
#
#           EndTime
# BarId
# 0.0    2020-01-02
# 40.0   2020-01-03
# 89.0   2020-01-06
# 132.0  2020-01-07
# 168.0  2020-01-08
# 220.0  2020-01-09
# 270.0  2020-01-10
# 358.0  2020-01-13
# 412.0  2020-01-14
# 457.0  2020-01-15
# 512.0  2020-01-16
# 599.0  2020-01-17
# 713.0  2020-01-21
# 784.0  2020-01-22
# 844.0  2020-01-23
# 945.0  2020-01-24
# 1021.0 2020-01-27
# 1122.0 2020-01-28
# 1216.0 2020-01-29
# 1268.0 2020-01-30

# %% [markdown]
# # 🔵 Graphs

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=corn.Date, y=corn.Close, name="Time Series"))
fig.add_trace(go.Scatter(x=corn1_dollar_bars["StartTime"], y=corn1_dollar_bars["Close"], name="Dollar Bars - T1"))
fig.add_trace(go.Scatter(x=corn_dollar_bars["StartTime"], y=corn_dollar_bars["Close"], name="Dollar Bars - T2"))

fig.show()

# %%
fig = go.Figure(
    go.Candlestick(x=corn_dollar_bars["StartTime"],
                   open=corn_dollar_bars["Open"],
                   high=corn_dollar_bars["High"],
                   low=corn_dollar_bars["Low"],
                   close=corn_dollar_bars["Close"])
)

fig.update_layout(
    title="Dollar Bars Candle Stick Graph",
    width=1200,
    height=600
)

fig.show()

# %%
corn = yf.download("ZC=F", start="2020-01-01", end="2023-12-31", interval="1d")
corn.columns = corn.columns.get_level_values(0)
corn.reset_index(inplace=True)
corn
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Date   Close    High     Low    Open  Volume
# 0     2020-01-02  391.50  392.00  387.25  387.75  103987
# 1     2020-01-03  386.50  392.00  385.50  391.50  125931
# 2     2020-01-06  384.75  387.75  382.75  386.25  112130
# 3     2020-01-07  384.50  385.75  383.50  385.00   93541
# 4     2020-01-08  384.25  385.50  382.25  384.00  135523
# ...          ...     ...     ...     ...     ...     ...
# 1001  2023-12-22  473.00  474.00  471.50  472.50   80484
# 1002  2023-12-26  480.25  481.00  471.50  473.00  114198
# 1003  2023-12-27  476.50  480.25  474.50  479.75  107950
# 1004  2023-12-28  474.25  478.75  474.00  476.00   99398
# 1005  2023-12-29  471.25  475.00  470.50  473.75  109649
#
# [1006 rows x 6 columns]

# %%
corn_dollar = get_dollar_bar(corn, 100_000_000_0)
corn_dollar
# Out:
#          Open    High     Low   Close   Volume  DollarVolume  StartTime  \
# BarId
# 0.0    387.75  394.00  375.25  387.25  2640795  1.021563e+09 2020-01-02
# 1.0    384.25  388.25  376.00  383.00  2580604  9.850633e+08 2020-01-27
# 2.0    382.25  388.50  332.00  335.25  2755668  1.013231e+09 2020-02-13
# 3.0    336.50  356.75  317.50  319.75  3005440  1.009171e+09 2020-03-19
# 4.0    319.75  330.75  300.25  324.00  3109274  9.892978e+08 2020-04-17
# ...       ...     ...     ...     ...      ...           ...        ...
# 61.0   476.25  490.00  455.75  488.75  2150872  1.025750e+09 2023-08-24
# 62.0   488.00  509.50  482.25  495.50  2133119  1.052591e+09 2023-10-03
# 63.0   494.25  497.00  468.00  468.50  1984429  9.476919e+08 2023-10-23
# 64.0   469.00  480.50  461.00  470.00  2116480  9.986897e+08 2023-11-08
# 65.0   468.75  484.00  447.00  471.25  1990072  9.296126e+08 2023-11-22
#
#          EndTime
# BarId
# 0.0   2020-01-24
# 1.0   2020-02-12
# 2.0   2020-03-18
# 3.0   2020-04-16
# 4.0   2020-06-03
# ...          ...
# 61.0  2023-10-02
# 62.0  2023-10-20
# 63.0  2023-11-07
# 64.0  2023-11-21
# 65.0  2023-12-29
#
# [66 rows x 8 columns]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=corn.Date, y=corn.Close, name="Time Series"))
fig.add_trace(go.Scatter(x=corn_dollar["StartTime"], y=corn_dollar["Close"], name="Dollar Bars - T2"))

fig.show()
